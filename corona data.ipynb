# %%
import pandas as pd

data = pd.read_csv('./data/Case.csv')
data.head(10)
# Out:
#    case_id province           city  group                 infection_case  \
# 0  1000001    Seoul     Yongsan-gu   True                  Itaewon Clubs
# 1  1000002    Seoul        Guro-gu   True            Guro-gu Call Center
# 2  1000003    Seoul  Dongdaemun-gu   True                  Dongan Church
# 3  1000004    Seoul        Guro-gu   True          Manmin Central Church
# 4  1000005    Seoul   Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
# 5  1000006    Seoul   Seongdong-gu   True               Seongdong-gu APT
# 6  1000007    Seoul      Jongno-gu   True        Jongno Community Center
# 7  1000008    Seoul     Gangnam-gu   True         Samsung Medical Center
# 8  1000009    Seoul        Jung-gu   True        Jung-gu Fashion Company
# 9  1000010    Seoul   Seodaemun-gu   True             Yeonana News Class
#
#    confirmed   latitude   longitude
# 0      133.0  37.538621  126.992652
# 1       99.0  37.508163  126.884387
# 2       20.0  37.592888  127.056766
# ...

# %%
# infection order 의미 ???

import numpy as np
import pandas as pd 

data2 = pd.read_csv('./data/PatientInfo.csv')
data2.head(30)
# Out:
#     patient_id  global_num     sex birth_year  age country province  \
# 0   1000000001         2.0    male       1964  50s   Korea    Seoul
# 1   1000000002         5.0    male       1987  30s   Korea    Seoul
# 2   1000000003         6.0    male       1964  50s   Korea    Seoul
# 3   1000000004         7.0    male       1991  20s   Korea    Seoul
# 4   1000000005         9.0  female       1992  20s   Korea    Seoul
# 5   1000000006        10.0  female       1966  50s   Korea    Seoul
# 6   1000000007        11.0    male       1995  20s   Korea    Seoul
# 7   1000000008        13.0    male       1992  20s   Korea    Seoul
# 8   1000000009        19.0    male       1983  30s   Korea    Seoul
# 9   1000000010        21.0  female       1960  60s   Korea    Seoul
# 10  1000000011        23.0  female       1962  50s   China    Seoul
# 11  1000000012        24.0    male       1992  20s   Korea    Seoul
# 12  1000000013        29.0    male       1938  80s   Korea    Seoul
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4004 entries, 0 to 4003
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          4004 non-null   int64
#  1   global_num          2806 non-null   float64
#  2   sex                 3674 non-null   object
#  3   birth_year          3267 non-null   object
#  4   age                 3525 non-null   object
#  5   country             4004 non-null   object
#  6   province            4004 non-null   object
#  7   city                3926 non-null   object
#  8   disease             18 non-null     object
#  9   infection_case      3211 non-null   object
#  10  infection_order     31 non-null     float64
#  11  infected_by         899 non-null    object
#  12  contact_number      680 non-null    object
#  13  symptom_onset_date  535 non-null    object
#  14  confirmed_date      4001 non-null   object
# ...

# %% [markdown]
# ###### data2

# %%
data3 = pd.read_csv('./data/PatientRoute.csv')
data3.head(10)
# Out:
#    patient_id  global_num        date     province           city  \
# 0  1000000001         2.0  2020-01-22  Gyeonggi-do       Gimpo-si
# 1  1000000001         2.0  2020-01-24        Seoul        Jung-gu
# 2  1000000002         5.0  2020-01-25        Seoul    Seongbuk-gu
# 3  1000000002         5.0  2020-01-26        Seoul    Seongbuk-gu
# 4  1000000002         5.0  2020-01-26        Seoul   Seongdong-gu
# 5  1000000002         5.0  2020-01-26        Seoul    Seongbuk-gu
# 6  1000000002         5.0  2020-01-26        Seoul    Seongbuk-gu
# 7  1000000002         5.0  2020-01-27        Seoul    Seongbuk-gu
# 8  1000000002         5.0  2020-01-27        Seoul  Dongdaemun-gu
# 9  1000000002         5.0  2020-01-28        Seoul    Seongbuk-gu
#
#                     type   latitude   longitude
# 0                airport  37.615246  126.715632
# 1               hospital  37.567241  127.005659
# 2                    etc  37.592560  127.017048
# ...

# %%
data4 = pd.read_csv('./data/Policy.csv')
data4
# Out:
#     policy_id country            type  \
# 0           1   Korea           Alert
# 1           2   Korea           Alert
# 2           3   Korea           Alert
# 3           4   Korea           Alert
# 4           5   Korea     Immigration
# 5           6   Korea     Immigration
# 6           7   Korea     Immigration
# 7           8   Korea     Immigration
# 8           9   Korea     Immigration
# 9          10   Korea     Immigration
# 10         11   Korea     Immigration
# 11         12   Korea     Immigration
# 12         13   Korea     Immigration
# 13         14   Korea     Immigration
# 14         15   Korea     Immigration
# 15         16   Korea     Immigration
# 16         17   Korea     Immigration
# 17         18   Korea     Immigration
# 18         19   Korea     Immigration
# 19         20   Korea          Health
# 20         21   Korea          Health
# 21         22   Korea          Health
# 22         23   Korea          Health
# ...

# %%
data5 = pd.read_csv('./data/Region.csv')
data5.head(10)
# Out:
#     code province          city   latitude   longitude  \
# 0  10000    Seoul         Seoul  37.566953  126.977977
# 1  10010    Seoul    Gangnam-gu  37.518421  127.047222
# 2  10020    Seoul   Gangdong-gu  37.530492  127.123837
# 3  10030    Seoul    Gangbuk-gu  37.639938  127.025508
# 4  10040    Seoul    Gangseo-gu  37.551166  126.849506
# 5  10050    Seoul     Gwanak-gu  37.478290  126.951502
# 6  10060    Seoul   Gwangjin-gu  37.538712  127.082366
# 7  10070    Seoul       Guro-gu  37.495632  126.887650
# 8  10080    Seoul  Geumcheon-gu  37.456852  126.895229
# 9  10090    Seoul      Nowon-gu  37.654259  127.056294
#
#    elementary_school_count  kindergarten_count  university_count  \
# 0                      607                 830                48
# 1                       33                  38                 0
# 2                       27                  32                 0
# 3                       14                  21                 0
# ...

# %%
data6= pd.read_csv('./data/SearchTrend.csv')
data6.tail(10)
# Out:
#             date     cold      flu  pneumonia  coronavirus
# 1603  2020-05-22  0.11590  0.10336    0.11881      3.55516
# 1604  2020-05-23  0.10626  0.04963    0.09063      2.91663
# 1605  2020-05-24  0.12126  0.04454    0.08245      2.84900
# 1606  2020-05-25  0.12963  0.05581    0.12499      3.24426
# 1607  2020-05-26  0.11699  0.05008    0.13372      3.21344
# 1608  2020-05-27  0.11326  0.05254    0.13017      3.93397
# 1609  2020-05-28  0.12081  0.04581    0.13890      5.55656
# 1610  2020-05-29  0.16454  0.04599    0.11699      4.95803
# 1611  2020-05-30  0.12208  0.03299    0.09090      3.41698
# 1612  2020-05-31  0.11990  0.03499    0.08436      3.25944

# %%
data7 = pd.read_csv('./data/SeoulFloating.csv')
data7.head(10)
# Out:
#          date  hour  birth_year     sex province           city  fp_num
# 0  2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1  2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2  2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# 3  2020-01-01     0          20    male    Seoul  Dongdaemun-gu   27050
# 4  2020-01-01     0          20  female    Seoul     Dongjag-gu   28880
# 5  2020-01-01     0          20    male    Seoul     Dongjag-gu   30350
# 6  2020-01-01     0          20  female    Seoul   Eunpyeong-gu   27750
# 7  2020-01-01     0          20    male    Seoul   Eunpyeong-gu   27910
# 8  2020-01-01     0          20  female    Seoul     Gangbuk-gu   19490
# 9  2020-01-01     0          20    male    Seoul     Gangbuk-gu   21940

# %%
data8 = pd.read_csv('./data/Time.csv')
data8.head(10)
# Out:
#          date  time  test  negative  confirmed  released  deceased
# 0  2020-01-20    16     1         0          1         0         0
# 1  2020-01-21    16     1         0          1         0         0
# 2  2020-01-22    16     4         3          1         0         0
# 3  2020-01-23    16    22        21          1         0         0
# 4  2020-01-24    16    27        25          2         0         0
# 5  2020-01-25    16    27        25          2         0         0
# 6  2020-01-26    16    51        47          3         0         0
# 7  2020-01-27    16    61        56          4         0         0
# 8  2020-01-28    16   116        97          4         0         0
# 9  2020-01-29    16   187       155          4         0         0

# %%
data9 = pd.read_csv('./data/TimeAge.csv')
data9.head(10)
# Out:
#          date  time  age  confirmed  deceased
# 0  2020-03-02     0   0s         32         0
# 1  2020-03-02     0  10s        169         0
# 2  2020-03-02     0  20s       1235         0
# 3  2020-03-02     0  30s        506         1
# 4  2020-03-02     0  40s        633         1
# 5  2020-03-02     0  50s        834         5
# 6  2020-03-02     0  60s        530         6
# 7  2020-03-02     0  70s        192         6
# 8  2020-03-02     0  80s         81         3
# 9  2020-03-03     0   0s         34         0

# %%
data10 = pd.read_csv('./data/TimeGender.csv')
data10.head(10)
# Out:
#          date  time     sex  confirmed  deceased
# 0  2020-03-02     0    male       1591        13
# 1  2020-03-02     0  female       2621         9
# 2  2020-03-03     0    male       1810        16
# 3  2020-03-03     0  female       3002        12
# 4  2020-03-04     0    male       1996        20
# 5  2020-03-04     0  female       3332        12
# 6  2020-03-05     0    male       2149        21
# 7  2020-03-05     0  female       3617        14
# 8  2020-03-06     0    male       2345        25
# 9  2020-03-06     0  female       3939        17

# %%
data11 = pd.read_csv('./data/TimeProvince.csv')
data11.head(10)
# Out:
#          date  time     province  confirmed  released  deceased
# 0  2020-01-20    16        Seoul          0         0         0
# 1  2020-01-20    16        Busan          0         0         0
# 2  2020-01-20    16        Daegu          0         0         0
# 3  2020-01-20    16      Incheon          1         0         0
# 4  2020-01-20    16      Gwangju          0         0         0
# 5  2020-01-20    16      Daejeon          0         0         0
# 6  2020-01-20    16        Ulsan          0         0         0
# 7  2020-01-20    16       Sejong          0         0         0
# 8  2020-01-20    16  Gyeonggi-do          0         0         0
# 9  2020-01-20    16   Gangwon-do          0         0         0

# %%
data12 = pd.read_csv('./data/Weather.csv')
data12.head(10)
# Out:
#     code           province        date  avg_temp  min_temp  max_temp  \
# 0  10000              Seoul  2016-01-01       1.2      -3.3       4.0
# 1  11000              Busan  2016-01-01       5.3       1.1      10.9
# 2  12000              Daegu  2016-01-01       1.7      -4.0       8.0
# 3  13000            Gwangju  2016-01-01       3.2      -1.5       8.1
# 4  14000            Incheon  2016-01-01       3.1      -0.4       5.7
# 5  15000            Daejeon  2016-01-01       1.6      -4.2       7.7
# 6  16000              Ulsan  2016-01-01       4.0      -1.6      12.0
# 7  20000        Gyeonggi-do  2016-01-01       1.6      -4.2       5.7
# 8  30000         Gangwon-do  2016-01-01       5.1       2.1       8.9
# 9  40000  Chungcheongbuk-do  2016-01-01      -1.0      -5.9       4.1
#
#    precipitation  max_wind_speed  most_wind_direction  avg_relative_humidity
# 0            0.0             3.5                 90.0                   73.0
# ...
