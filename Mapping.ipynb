# %%
import pandas as pd
import numpy as np
import folium

# %%
state_data = pd.read_excel('data2/population1.xlsx', encoding='cp949')
state_data['Code'] = state_data['Code'].astype(str)

# %%
type(state_data['week1'][0])
# Out:
# numpy.int64

# %%
state_data
# Out:
#    Code  20200815  20200816  20200817  20200818  20200819  20200820  20200821  \
# 0    11        72       141        89       131       150       135       125
# 1    26         3         6         7         7         9        15         8
# 2    27         0         1         1         6         2         2         4
# 3    28         6         8         7        18         8        10        17
# 4    29         1         7         7         3         4         1         5
# 5    30         1         0         2         0         0         8         6
# 6    31         0         1         0         2         0         0         1
# 7    36         0         0         0         0         1         0         3
# 8    41        67        96        67        52        94        81       102
# 9    42         3         0         1         2         5         5         9
# 10   43         0         1         2         1         1         1         3
# ...

# %%
state_geo = './data2/TL_SCCO_CTPRVN.json'
rfile = open(state_geo, 'r', encoding='UTF8').read()

# %%
type(jsonData['features'][0]['properties']['CTPRVN_CD'])
# Out:
# str

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=rfile,
    name='감염자수',
    data=state_data,
    columns=['Code', 'week1'],
    key_on='feature.properties.CTPRVN_CD',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '감염자수',
    threshold_scale = [0, 100, 500, 750, 1000, 1500, 2000, 3000]
)

folium.LayerControl().add_to(m)

m.save('folium_kr1.html')

# %% [markdown]
# #### week1주차 감염자

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### week2 누적 확진자

# %%
state_data['total'] = state_data['week1'] + state_data['week2']

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=rfile,
    name='감염자수',
    data=state_data,
    columns=['Code', 'total'],
    key_on='feature.properties.CTPRVN_CD',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '감염자수',
    threshold_scale = [0, 100, 500, 750, 1000, 1500, 2000, 3000]
)

folium.LayerControl().add_to(m)
m.save('folium_kr2.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### week3 누적확진자

# %%
state_data['total2'] = state_data['week3'] + state_data['total']

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=rfile,
    name='감염자수',
    data=state_data,
    columns=['Code', 'total2'],
    key_on='feature.properties.CTPRVN_CD',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '감염자수',
    threshold_scale = [0, 100, 500, 750, 1000, 1500, 2000, 3000]
)

folium.LayerControl().add_to(m)
m.save('folium_kr3.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### week4 누적확진자

# %%
state_data['total3'] = state_data['week4'] + state_data['total2']

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=rfile,
    name='인구수',
    data=state_data,
    columns=['Code', 'total3'],
    key_on='feature.properties.CTPRVN_CD',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '감염자수',
    threshold_scale = [0, 100, 500, 750, 1000, 1500, 2000, 3000]
)

folium.LayerControl().add_to(m)
m.save('folium_kr4.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 8월15일전

# %%
state_data = pd.read_excel('data2/population.xlsx', encoding='cp949')
state_data['Code'] = state_data['Code'].astype(str)

# %%
state_data
# Out:
#    Code  before0815  after0815
# 0    11        1404       3922
# 1    26         155        285
# 2    27        6881       7010
# 3    28         311        704
# 4    29         185        375
# 5    30         147        268
# 6    31          36         81
# 7    36          45         58
# 8    41        1274       3106
# 9    42          54        185
# 10   43          63        114
# 11   44         166        334
# 12   45          18         63
# 13   46          18        129
# 14   47        1375       1428
# 15   48         112        191
# 16   50          11         32

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=rfile,
    name='인구수',
    data=state_data,
    columns=['Code', 'before0815'],
    key_on='feature.properties.CTPRVN_CD',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '감염자수',
    threshold_scale = [0, 100, 500, 750, 1000, 1500, 2000, 3000, 5000, 8000]
)

folium.LayerControl().add_to(m)
m.save('folium_kr5.html')
# Out:
# C:\Users\MyLaptop\anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 0815 이후

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=rfile,
    name='인구수',
    data=state_data,
    columns=['Code', 'after0815'],
    key_on='feature.properties.CTPRVN_CD',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '감염자수',
    threshold_scale = [0, 100, 500, 750, 1000, 1500, 2000, 3000, 5000, 8000]
)

folium.LayerControl().add_to(m)
m.save('folium_kr6.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
